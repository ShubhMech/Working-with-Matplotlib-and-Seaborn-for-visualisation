# %%
path = r"D:\Asus\Documents\stocks.csv"

# %%
import datetime as dta

# %%
stocks_= pd.read_csv(path)

# %%
stocks_.head()
# Out:
#          Date        AAPL       IBM      CSCO      MSFT
# 0  2000-01-03  111.937502  116.0000  108.0625  116.5625
# 1  2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2  2000-01-05  103.999997  116.0000  101.6875  113.8125
# 3  2000-01-06   94.999998  114.0000  100.0000  110.0000
# 4  2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
pd.to_datetime(stocks_['Date']).dt.day
# Out:
# 0        3
# 1        4
# 2        5
# 3        6
# 4        7
#         ..
# 3516    24
# 3517    26
# 3518    27
# 3519    30
# 3520    31
# Name: Date, Length: 3521, dtype: int64

# %%
pd.to_datetime(stocks_['Date']).dt.year
# Out:
# 0       2000
# 1       2000
# 2       2000
# 3       2000
# 4       2000
#         ...
# 3516    2013
# 3517    2013
# 3518    2013
# 3519    2013
# 3520    2013
# Name: Date, Length: 3521, dtype: int64

# %%
pd.to_datetime(stocks_['Date']).dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 3516    12
# 3517    12
# 3518    12
# 3519    12
# 3520    12
# Name: Date, Length: 3521, dtype: int64

# %%
pd.to_datetime(stocks_['Date']).dt.week
# Out:
# <ipython-input-100-3264693ced68>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   pd.to_datetime(stocks_['Date']).dt.week
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 3516    52
# 3517    52
# 3518    52
# 3519     1
# 3520     1
# Name: Date, Length: 3521, dtype: int64

# %%
pd.to_datetime(stocks_['Date']).dt.strftime('%B %Y')
# Out:
# 0        January 2000
# 1        January 2000
# 2        January 2000
# 3        January 2000
# 4        January 2000
#             ...
# 3516    December 2013
# 3517    December 2013
# 3518    December 2013
# 3519    December 2013
# 3520    December 2013
# Name: Date, Length: 3521, dtype: object

# %%
dta.date(2022,1,23)-dta.date(2017,4,8)
# Out:
# datetime.timedelta(days=1751)

# %%
dta.datetime.today()
# Out:
# datetime.datetime(2022, 1, 24, 19, 18, 41, 889651)

# %%
# stocks_.set_index(['Date Joined'], inplace= True)

# %%
stocks_['Date']= pd.to_datetime(stocks_['Date'])

# %%
# stocks_.groupby('Name').max()

# %%
# stocks_['Date Joined'].max()- stocks_.groupby('Name')['Date Joined'].max()

# %%
stocks_
# Out:
#            Date        AAPL         IBM        CSCO        MSFT
# 0    2000-01-03  111.937502  116.000000  108.062500  116.562500
# 1    2000-01-04  102.500003  112.062500  102.000000  112.625000
# 2    2000-01-05  103.999997  116.000000  101.687500  113.812500
# 3    2000-01-06   94.999998  114.000000  100.000000  110.000000
# 4    2000-01-07   99.500001  113.500000  105.875000  111.437500
# ...         ...         ...         ...         ...         ...
# 3516 2013-12-24  567.669975  183.220001   21.690001   37.080002
# 3517 2013-12-26  563.900009  185.350006   21.799999   37.439999
# 3518 2013-12-27  560.089989  185.080002   22.020000   37.290001
# 3519 2013-12-30  554.519981  186.410004   22.250000   37.290001
# 3520 2013-12-31  561.019997  187.570007   22.430000   37.410000
#
# [3521 rows x 5 columns]

# %%
str1= "31.Jul.15"
str2= "31.Aug.14"

# %%
str2>str1
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %%
# type(stocks_['Date Joined'].max()- stocks_.groupby('Name')['Date Joined'].max())

# %%
# (stocks_['Date Joined'].max()- stocks_.groupby('Name')['Date Joined'].max()).dt.components.days

# %%
# plt.hist((stocks_['Date']- stocks_.groupby('Name')['Date Joined'].max()).dt.components.days)

# %%
# ff=(stocks_['Date Joined'].max()- stocks_.groupby('Name')['Date Joined'].max())

# %%
# vals=(ff.values)/(10**9*60*60*24)

# %%
# vals.shape

# %%
stocks_['Last Date']=stocks_.shift(1)['Date']

# %%
stocks_
# Out:
#            Date        AAPL         IBM        CSCO        MSFT  Last Date
# 0    2000-01-03  111.937502  116.000000  108.062500  116.562500        NaT
# 1    2000-01-04  102.500003  112.062500  102.000000  112.625000 2000-01-03
# 2    2000-01-05  103.999997  116.000000  101.687500  113.812500 2000-01-04
# 3    2000-01-06   94.999998  114.000000  100.000000  110.000000 2000-01-05
# 4    2000-01-07   99.500001  113.500000  105.875000  111.437500 2000-01-06
# ...         ...         ...         ...         ...         ...        ...
# 3516 2013-12-24  567.669975  183.220001   21.690001   37.080002 2013-12-23
# 3517 2013-12-26  563.900009  185.350006   21.799999   37.439999 2013-12-24
# 3518 2013-12-27  560.089989  185.080002   22.020000   37.290001 2013-12-26
# 3519 2013-12-30  554.519981  186.410004   22.250000   37.290001 2013-12-27
# 3520 2013-12-31  561.019997  187.570007   22.430000   37.410000 2013-12-30
#
# [3521 rows x 6 columns]

# %%
# aa=stocks_.groupby([ 'Customer ID', 'Date Joined'], as_index=False).count()

# %%
# bb=aa.loc[:,[ 'Customer ID','Date Joined']]

# %%
# bb['Previos Recorded Date']= bb.shift(1)['Date Joined']

# %%
# stocks_['Customer ID'].nunique()

# %%
# bb

# %%
stocks_.set_index('Date', inplace=True)

# %%
stocks_.tail(10)
# Out:
#                   AAPL         IBM       CSCO       MSFT  Last Date
# Date
# 2013-12-17  554.990005  175.759995  20.920000  36.520000 2013-12-16
# 2013-12-18  550.769989  178.699997  21.000000  36.580002 2013-12-17
# 2013-12-19  544.459991  180.220001  21.070000  36.250000 2013-12-18
# 2013-12-20  549.019989  180.020004  21.129999  36.799999 2013-12-19
# 2013-12-23  570.090004  182.229996  21.570000  36.619999 2013-12-20
# 2013-12-24  567.669975  183.220001  21.690001  37.080002 2013-12-23
# 2013-12-26  563.900009  185.350006  21.799999  37.439999 2013-12-24
# 2013-12-27  560.089989  185.080002  22.020000  37.290001 2013-12-26
# 2013-12-30  554.519981  186.410004  22.250000  37.290001 2013-12-27
# 2013-12-31  561.019997  187.570007  22.430000  37.410000 2013-12-30

# %%
(stocks_['IBM'].resample('M').mean()).plot()
(stocks_['AAPL'].resample('D').mean()).plot()
plt.legend()

# %%
(stocks_['AAPL'].resample('D').mean()).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(stocks_['AAPL'].resample('Y').mean()).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# stocks_.sort_values('Customer ID',inplace= True)

# %%
plt.figure(figsize=[30,10])
plt.plot(stocks_.index, stocks_['CSCO'])

# %%
sns.distplot(stocks_['CSCO'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CSCO', ylabel='Density'>

# %%
from scipy.stats import kstest

# %%
kstest(stocks_['IBM'],cdf='norm',args=[stocks_['IBM'].mean(),stocks_['IBM'].std()])
# Out:
# KstestResult(statistic=0.14062231186996976, pvalue=3.300074849036131e-61)

# %%
sns.distplot(stocks_['IBM'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='IBM', ylabel='Density'>

# %%
kstest(stocks_['IBM'],cdf='norm',args=[stocks_['CSCO'].mean(),stocks_['IBM'].std()])
# Out:
# KstestResult(statistic=0.8715600316709464, pvalue=0.0)

# %%
sns.pairplot(stocks_)

# %%
plt.figure(figsize=[30,10])
plt.hist(stocks_['IBM'],bins=40
        )
# Out:
# (array([  6.,   7.,   9.,  24.,  63., 160., 316., 262., 216., 252., 165.,
#         134., 186., 122., 153., 187., 127., 132., 154.,  28.,   8.,  18.,
#          41.,   8.,   3.,  10.,  39.,  50.,  36.,  31.,  37.,  57.,  71.,
#          64., 117.,  61.,  51.,  62.,  38.,  16.]),
#  array([ 55.07      ,  59.08825007,  63.10650015,  67.12475022,
#          71.1430003 ,  75.16125038,  79.17950045,  83.19775053,
#          87.2160006 ,  91.23425067,  95.25250075,  99.27075082,
#         103.2890009 , 107.30725098, 111.32550105, 115.34375113,
#         119.3620012 , 123.38025128, 127.39850135, 131.41675143,
#         135.4350015 , 139.45325157, 143.47150165, 147.48975172,
#         151.5080018 , 155.52625188, 159.54450195, 163.56275203,
#         167.5810021 , 171.59925218, 175.61750225, 179.63575232,
#         183.6540024 , 187.67225247, 191.69050255, 195.70875262,
#         199.7270027 , 203.74525277, 207.76350285, 211.78175293,
#         215.800003  ]),
# ...

# %%
sns.scatterplot( stocks_['IBM'],stocks_['AAPL'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IBM', ylabel='AAPL'>

# %%
plt.figure(figsize=[30,10])
plt.scatter(stocks_.index,stocks_['IBM']
        )

# %%
plt.figure(figsize=[20,5])
sns.scatterplot(stocks_.index,stocks_['IBM'], hue= stocks_['IBM'],
        )
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='IBM'>
