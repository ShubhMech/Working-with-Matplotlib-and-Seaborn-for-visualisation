# %%
path= r"D:\Asus\Documents\cars04.csv"

# %%
import pandas as pd

# %%
cars=pd.read_csv(path)

# %%
cars
# Out:
#                                 name  sports_car    suv  wagon  minivan  \
# 0                 Chevrolet Aveo 4dr       False  False  False    False
# 1        Chevrolet Aveo LS 4dr hatch       False  False  False    False
# 2             Chevrolet Cavalier 2dr       False  False  False    False
# 3             Chevrolet Cavalier 4dr       False  False  False    False
# 4          Chevrolet Cavalier LS 2dr       False  False  False    False
# ..                               ...         ...    ...    ...      ...
# 423         Nissan Titan King Cab XE       False  False  False    False
# 424                      Subaru Baja       False  False  False    False
# 425                    Toyota Tacoma       False  False  False    False
# 426     Toyota Tundra Regular Cab V6       False  False  False    False
# 427  Toyota Tundra Access Cab V6 SR5       False  False  False    False
#
#      pickup  all_wheel  rear_wheel   msrp  dealer_cost  eng_size  ncyl  \
# ...

# %%
import seaborn as sns

# %%
sns.countplot(cars['ncyl'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ncyl', ylabel='count'>

# %%
sns.scatterplot(cars['weight'],cars['length'], hue=cars['ncyl'].astype('category'))
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='weight', ylabel='length'>

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         428 non-null    object
#  1   sports_car   428 non-null    bool
#  2   suv          428 non-null    bool
#  3   wagon        428 non-null    bool
#  4   minivan      428 non-null    bool
#  5   pickup       428 non-null    bool
#  6   all_wheel    428 non-null    bool
#  7   rear_wheel   428 non-null    bool
#  8   msrp         428 non-null    int64
#  9   dealer_cost  428 non-null    int64
#  10  eng_size     428 non-null    float64
#  11  ncyl         428 non-null    int64
#  12  horsepwr     428 non-null    int64
#  13  city_mpg     414 non-null    float64
#  14  hwy_mpg      414 non-null    float64
#  15  weight       426 non-null    float64
#  16  wheel_base   426 non-null    float64
#  17  length       402 non-null    float64
# ...

# %%
cars['ncyl']=cars['ncyl'].astype('category')

# %%
plt.figure(figsize=[30,10])
sns.scatterplot(cars['weight'],cars['length'], hue=cars['ncyl'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='weight', ylabel='length'>

# %%
cars['ncyl'].unique()
# Out:
# [4, 6, 3, 8, 5, 12, 10, -1]
# Categories (8, int64): [-1, 3, 4, 5, 6, 8, 10, 12]

# %%
sns.countplot(cars['suv'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='suv', ylabel='count'>

# %%
sns.countplot(cars['wagon'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='wagon', ylabel='count'>

# %%
plt.figure(figsize=[30,10])
sns.countplot(cars['eng_size'])
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='eng_size', ylabel='count'>

# %%
cars['name'].unique()
# Out:
# array(['Chevrolet Aveo 4dr', 'Chevrolet Aveo LS 4dr hatch',
#        'Chevrolet Cavalier 2dr', 'Chevrolet Cavalier 4dr',
#        'Chevrolet Cavalier LS 2dr', 'Dodge Neon SE 4dr',
#        'Dodge Neon SXT 4dr', 'Ford Focus ZX3 2dr hatch',
#        'Ford Focus LX 4dr', 'Ford Focus SE 4dr', 'Ford Focus ZX5 5dr',
#        'Honda Civic DX 2dr', 'Honda Civic HX 2dr', 'Honda Civic LX 4dr',
#        'Hyundai Accent 2dr hatch', 'Hyundai Accent GL 4dr',
#        'Hyundai Accent GT 2dr hatch', 'Hyundai Elantra GLS 4dr',
#        'Hyundai Elantra GT 4dr', 'Hyundai Elantra GT 4dr hatch',
#        'Kia Optima LX 4dr', 'Kia Rio 4dr manual', 'Kia Rio 4dr auto',
#        'Kia Spectra 4dr', 'Kia Spectra GS 4dr hatch',
#        'Kia Spectra GSX 4dr hatch', 'Mazda3 i 4dr', 'Mini Cooper',
#        'Mitsubishi Lancer ES 4dr', 'Mitsubishi Lancer LS 4dr',
#        'Nissan Sentra 1.8 4dr', 'Nissan Sentra 1.8 S 4dr',
#        'Pontiac Sunfire 1SA 2dr', 'Saturn Ion1 4dr', 'Saturn lon2 4dr',
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         428 non-null    object
#  1   sports_car   428 non-null    bool
#  2   suv          428 non-null    bool
#  3   wagon        428 non-null    bool
#  4   minivan      428 non-null    bool
#  5   pickup       428 non-null    bool
#  6   all_wheel    428 non-null    bool
#  7   rear_wheel   428 non-null    bool
#  8   msrp         428 non-null    int64
#  9   dealer_cost  428 non-null    int64
#  10  eng_size     428 non-null    float64
#  11  ncyl         428 non-null    category
#  12  horsepwr     428 non-null    int64
#  13  city_mpg     414 non-null    float64
#  14  hwy_mpg      414 non-null    float64
#  15  weight       426 non-null    float64
#  16  wheel_base   426 non-null    float64
#  17  length       402 non-null    float64
# ...

# %%
cars[(cars['name']== 'Chevrolet Cavalier LS 2dr') & (cars['name']== 'Chevrolet Aveo 4dr')]
# Out:
# Empty DataFrame
# Columns: [name, sports_car, suv, wagon, minivan, pickup, all_wheel, rear_wheel, msrp, dealer_cost, eng_size, ncyl, horsepwr, city_mpg, hwy_mpg, weight, wheel_base, length, width]
# Index: []

# %%
sns.barplot(x=cars['ncyl'],y=cars['rear_wheel'])
# Out:
# <AxesSubplot:xlabel='ncyl', ylabel='rear_wheel'>

# %%
plt.hist(x=cars['horsepwr'])
plt.xlabel('hp')
# Out:
# Text(0.5, 0, 'hp')

# %%
cars[cars['ncyl']==10]
# Out:
#                          name  sports_car    suv  wagon  minivan  pickup  \
# 271  Mazda RX-8 4dr automatic        True  False  False    False   False
# 272     Mazda RX-8 4dr manual        True  False  False    False   False
#
#      all_wheel  rear_wheel   msrp  dealer_cost  eng_size ncyl  horsepwr  \
# 271      False        True  25700        23794       1.3   -1       197
# 272      False        True  27200        25179       1.3   -1       238
#
#      city_mpg  hwy_mpg  weight  wheel_base  length  width
# 271      18.0     25.0  3053.0       106.0   174.0    NaN
# 272      18.0     24.0  3029.0       106.0   174.0    NaN

# %%
cars
# Out:
#                                 name  sports_car    suv  wagon  minivan  \
# 0                 Chevrolet Aveo 4dr       False  False  False    False
# 1        Chevrolet Aveo LS 4dr hatch       False  False  False    False
# 2             Chevrolet Cavalier 2dr       False  False  False    False
# 3             Chevrolet Cavalier 4dr       False  False  False    False
# 4          Chevrolet Cavalier LS 2dr       False  False  False    False
# ..                               ...         ...    ...    ...      ...
# 423         Nissan Titan King Cab XE       False  False  False    False
# 424                      Subaru Baja       False  False  False    False
# 425                    Toyota Tacoma       False  False  False    False
# 426     Toyota Tundra Regular Cab V6       False  False  False    False
# 427  Toyota Tundra Access Cab V6 SR5       False  False  False    False
#
#      pickup  all_wheel  rear_wheel   msrp  dealer_cost  eng_size ncyl  \
# ...

# %%
cars['wheel_base'].plot(kind='bar',figsize=(300,37))
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=cars['ncyl'],y=cars['rear_wheel'])
# Out:
# <AxesSubplot:xlabel='ncyl', ylabel='rear_wheel'>

# %%
plt.bar(x=cars.groupby('ncyl').mean()['eng_size'],height=cars.groupby('ncyl').mean()['city_mpg'])
# Out:
# <BarContainer object of 8 artists>

# %%
cars.groupby('ncyl').mean()
# Out:
#       sports_car       suv     wagon   minivan    pickup  all_wheel  \
# ncyl
# -1      1.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 3       0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 4       0.080882  0.051471  0.102941  0.007353  0.044118   0.132353
# 5       0.000000  0.000000  0.142857  0.000000  0.000000   0.571429
# 6       0.105263  0.157895  0.057895  0.100000  0.047368   0.215789
# 8       0.160920  0.252874  0.045977  0.000000  0.103448   0.321839
# 10      0.500000  0.500000  0.000000  0.000000  0.000000   0.500000
# 12      0.333333  0.000000  0.000000  0.000000  0.000000   0.000000
#
#       rear_wheel           msrp    dealer_cost  eng_size    horsepwr  \
# ncyl
# -1      1.000000   26450.000000   24486.500000  1.300000  217.500000
# 3       0.000000   19110.000000   17911.000000  2.000000   73.000000
# 4       0.080882   19747.500000   18352.669118  2.058824  150.514706
# ...
